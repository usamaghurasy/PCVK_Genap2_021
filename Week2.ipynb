# %% [markdown]
# <a href="https://colab.research.google.com/github/usamaghurasy/PCVK_Genap2_021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kucing.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
plt.figure(figsize=(3,3))
plt.imshow(img3)

# %%
img4 = img3
#Red - Green
img4[:,:,0] = np.zeros([img4.shape[0], img4.shape[1]])
plt.imshow(img4)

# %% [markdown]
# Tampilan gambar dalam channel Red-Green

# %%
#Blue - Green
img5 = img3

img5[:,:,2] = np.zeros([img5.shape[0], img5.shape[1]])
plt.imshow(img5)

# %% [markdown]
# Tampilan image dalam channel Green-Blue

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %%
plt.imshow(img5[5:30])

# %% [markdown]
# Tampilan gambar baris 5-30 berwarna hijau

# %%
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(5):
  startp = random.randint(0,350)
  endp = random.randint(0,350)

  c1 = random.randint(0,255)
  c2 = random.randint(0,255)
  c3 = random.randint(0,255)
  start_point = (startp , startp) 
    
  end_point = (endp, endp) 
    
  color = (c1, c2, c3) 
    
  thickness = 7
    
  img6 = cv.rectangle(img3, start_point, end_point, color, thickness) 
    
# Displaying the image  
plt.imshow(img6)

# %% [markdown]
# Buat 5 kotak berbagai ukuran dan warna yang berbeda dala msatu gambar. disarankan menggunakan bilangan acak/random

# %%
img7 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img7)

# %% [markdown]
# Tampilan gambar dengan posisi terbalik

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kucing.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna "gray"

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna"magma"

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK/Images/kucing.jpg', img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,250,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-2)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Setelah semua kode selesai simpan "Week2.ipynb" pada GitHub Anda dengan memilih File kemudian "Save a copy in GitHub

# %% [markdown]
# **PERTANYAAN**

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# Jawab:
#
#     gambar yang ditampilkan dengan menggunakan matplotlib memvisualisasikan grafik yang terdapat satu sumbu atau lebih, mempresentasikan warna dan glyphs. sedangkan gambar yang ditampilkan tidak menggunakanmatplotlib tidak dapat memvisualisasikan seperti pada gambar yang menggunakan matplotlip

# %% [markdown]
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe dan int6 dan int32?
#
# Jawab:
#
#   Perbedaan pada ukuran gambar,tergantung int. semakin kecil tipe intnya maka semakin sedikit juga kapasitasnya dan begitu juga sebaliknya

# %% [markdown]
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))?
#
# Jawab:
#
#   Reshape digunakan untuk mengubah bentuk bangun

# %% [markdown]
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut?
#
# Jawab:
#
#   Kode dibaris atas menambahkan satu patches karena cv.imshow tidak berjalan di Google Colab maupun di Jupyter Notebook.Variabel img merupakan citra asli, sementara grayImg yang sudah dikonversi ke hitam putih (gray)

# %% [markdown]
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
#
# Jawab:
#
#  untuk memuat gambar serta read-write gambar

# %% [markdown]
# TUGAS Berdasarkan praktikum bagian 3 dan 4

# %%
img_sc7 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_sc7,pt1=(100,450),pt2=(550,50),color=(255,255,255),thickness=3)
cv.circle(img_sc7,center=(350,250),radius=200,color=(255,0,0),thickness=3)
plt.imshow(img_sc7)

# %% [markdown]
# Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kucing.jpg

# %%
img_sc8 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_sc8,pt1=(0,400),pt2=(100,500),color=(0,0,255),thickness=3)
plt.imshow(img_sc8)
